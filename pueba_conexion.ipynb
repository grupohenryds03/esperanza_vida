# %%
import snowflake.connector
from snow import *
import pandas as pd

# %% [markdown]
# esto es una prueba

# %%
conn=snowflake.connector.connect(
        user=snow_user,
        password=snow_password,
        account=snow_account,
        warehouse=snow_warehouse,
        database=snow_database)

# %%
sql_ind="SELECT i.ID_INDICADOR , i.CODIGO, i.DESCRIPCION FROM INDICADOR i JOIN (SELECT DISTINCT ID_INDICADOR FROM EV) e ON e.ID_INDICADOR=i.ID_INDICADOR"
df_ind=pd.read_sql(sql_ind,conn) # dataframe indicadores
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
df_ind
# Out:
#     ID_INDICADOR             CODIGO  \
# 0              5     EN.ATM.CO2E.KT
# 1             33        SP.POP.GROW
# 2              2      CSV1 from WHO
# 3             20        SH.IMM.IDPT
# 4             21        SH.IMM.MEAS
# 5             18        SH.DYN.MORT
# 6              3      CSV2 from WHO
# 7             18        SH.DYN.MORT
# 8             29     SP.DYN.AMRT.MA
# 9             28     SP.DYN.AMRT.FE
# 10            27  SL.UEM.TOTL.NE.ZS
# 11            32  SP.DYN.LE00.MA.IN
# 12            30  SP.DYN.LE00.FE.IN
# 13            31     SP.DYN.LE00.IN
# 14             9     NY.GDP.PCAP.KD
# 15            35     SP.RUR.TOTL.ZS
# 16            36  SP.URB.TOTL.IN.ZS
# 17             1  BG.GSR.NFSV.GD.ZS
#
#                                           DESCRIPCION
# 0                               emisiones de CO2 (kt)
# 1               crecimiento de la poblacion (% anual)
# 2   Hepatitis B (HepB3) immunization coverage amon...
# 3   Immunization, DPT (% of children ages 12-23 mo...
# 4   Immunization, measles (% of children ages 12-2...
# 5     Mortality rate, under-5 (per 1,000 live births)
# 6   Polio (Pol3) immunization covergae among 1-yea...
# 7   tasa de mortalidad menores de 5 años (por 1000...
# 8   tasa de mortalidad, adultos hombres (por cada ...
# 9   tasa de mortalidad, adultos mujeres (por cada ...
# 10        desempleo total (% de la poblacion laboral)
# 11         esperanza de vida al nacer, hombres (años)
# 12         esperanza de vida al nacer, muejres (años)
# 13           esperanza de vida al nacer, Total (años)
# 14                 GDP per capita (constant 2015 US$)
# 15          Población Rural (% de la poblacion total)
# 16                poblacion urbana (%poblacion total)
# 17                       Trade in services (% of GDP)
